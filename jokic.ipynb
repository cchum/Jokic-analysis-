# %%
import pandas as pd

# %%
data = pd.read_csv('jokic.csv')

# %%
data.shape
# Out:
# (12, 31)

# %%
data.head(12)
# Out:
#      Season                              Age                             Team  \
# 0   2014-15  Did not play - other pro league  Did not play - other pro league
# 1   2015-16                               20                              DEN
# 2   2016-17                               21                              DEN
# 3   2017-18                               22                              DEN
# 4   2018-19                               23                              DEN
# 5   2019-20                               24                              DEN
# 6   2020-21                               25                              DEN
# 7   2021-22                               26                              DEN
# 8   2022-23                               27                              DEN
# 9   2023-24                               28                              DEN
# 10  2024-25                               29                              DEN
# ...

# %%
data.drop(index=0, inplace=True)
data.drop(index=11, inplace=True)

# %%
data.reset_index(drop=True)
# Out:
#     Season Age Team   Lg Pos   G  GS    MP    FG   FGA  ...  ORB   DRB   TRB  \
# 0  2015-16  20  DEN  NBA   C  80  55  21.7   3.8   7.5  ...  2.3   4.7   7.0
# 1  2016-17  21  DEN  NBA   C  73  59  27.9   6.8  11.7  ...  2.9   6.9   9.8
# 2  2017-18  22  DEN  NBA   C  75  73  32.6   6.7  13.5  ...  2.6   8.1  10.7
# 3  2018-19  23  DEN  NBA   C  80  80  31.3   7.7  15.1  ...  2.9   8.0  10.8
# 4  2019-20  24  DEN  NBA   C  73  73  32.0   7.7  14.7  ...  2.3   7.5   9.7
# 5  2020-21  25  DEN  NBA   C  72  72  34.6  10.2  18.0  ...  2.8   8.0  10.8
# 6  2021-22  26  DEN  NBA   C  74  74  33.5  10.3  17.7  ...  2.8  11.0  13.8
# 7  2022-23  27  DEN  NBA   C  69  69  33.7   9.4  14.8  ...  2.4   9.4  11.8
# 8  2023-24  28  DEN  NBA   C  79  79  34.6  10.4  17.9  ...  2.8   9.5  12.4
# 9  2024-25  29  DEN  NBA   C  70  70  36.7  11.2  19.5  ...  2.9   9.9  12.7
#
#     AST  STL  BLK  TOV   PF   PTS              Awards
# 0   2.4  1.0  0.6  1.3  2.6  10.0               ROY-3
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 1 to 10
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Season  10 non-null     object
#  1   Age     10 non-null     object
#  2   Team    10 non-null     object
#  3   Lg      10 non-null     object
#  4   Pos     10 non-null     object
#  5   G       10 non-null     object
#  6   GS      10 non-null     object
#  7   MP      10 non-null     object
#  8   FG      10 non-null     object
#  9   FGA     10 non-null     object
#  10  FG%     10 non-null     object
#  11  3P      10 non-null     object
#  12  3PA     10 non-null     object
#  13  3P%     10 non-null     object
#  14  2P      10 non-null     object
#  15  2PA     10 non-null     object
#  16  2P%     10 non-null     object
#  17  eFG%    10 non-null     object
#  18  FT      10 non-null     object
#  19  FTA     10 non-null     object
#  20  FT%     10 non-null     object
# ...

# %%
data = data.drop(columns=['Team', 'Lg', 'Pos'])

# %%
data['Awards'] = data['Awards'].fillna('No awards')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 1 to 10
# Data columns (total 28 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Season  10 non-null     object
#  1   Age     10 non-null     object
#  2   G       10 non-null     object
#  3   GS      10 non-null     object
#  4   MP      10 non-null     object
#  5   FG      10 non-null     object
#  6   FGA     10 non-null     object
#  7   FG%     10 non-null     object
#  8   3P      10 non-null     object
#  9   3PA     10 non-null     object
#  10  3P%     10 non-null     object
#  11  2P      10 non-null     object
#  12  2PA     10 non-null     object
#  13  2P%     10 non-null     object
#  14  eFG%    10 non-null     object
#  15  FT      10 non-null     object
#  16  FTA     10 non-null     object
#  17  FT%     10 non-null     object
#  18  ORB     10 non-null     object
#  19  DRB     10 non-null     object
#  20  TRB     10 non-null     object
# ...

# %%
data
# Out:
#      Season Age   G  GS    MP    FG   FGA   FG%   3P  3PA  ...  ORB   DRB  \
# 1   2015-16  20  80  55  21.7   3.8   7.5  .512  0.4  1.1  ...  2.3   4.7
# 2   2016-17  21  73  59  27.9   6.8  11.7  .578  0.6  1.9  ...  2.9   6.9
# 3   2017-18  22  75  73  32.6   6.7  13.5  .499  1.5  3.7  ...  2.6   8.1
# 4   2018-19  23  80  80  31.3   7.7  15.1  .511  1.0  3.4  ...  2.9   8.0
# 5   2019-20  24  73  73  32.0   7.7  14.7  .528  1.1  3.5  ...  2.3   7.5
# 6   2020-21  25  72  72  34.6  10.2  18.0  .566  1.3  3.3  ...  2.8   8.0
# 7   2021-22  26  74  74  33.5  10.3  17.7  .583  1.3  3.9  ...  2.8  11.0
# 8   2022-23  27  69  69  33.7   9.4  14.8  .632  0.8  2.2  ...  2.4   9.4
# 9   2023-24  28  79  79  34.6  10.4  17.9  .583  1.1  2.9  ...  2.8   9.5
# 10  2024-25  29  70  70  36.7  11.2  19.5  .576  2.0  4.7  ...  2.9   9.9
#
#      TRB   AST  STL  BLK  TOV   PF   PTS              Awards
# 1    7.0   2.4  1.0  0.6  1.3  2.6  10.0               ROY-3
# ...

# %%
for col in data.columns:
    if col not in ['Awards', 'Season']:
        data[col] = pd.to_numeric(data[col], errors='coerce')

# %%
data.dtypes
# Out:
# Season     object
# Age         int64
# G           int64
# GS          int64
# MP        float64
# FG        float64
# FGA       float64
# FG%       float64
# 3P        float64
# 3PA       float64
# 3P%       float64
# 2P        float64
# 2PA       float64
# 2P%       float64
# eFG%      float64
# FT        float64
# FTA       float64
# FT%       float64
# ORB       float64
# DRB       float64
# TRB       float64
# AST       float64
# STL       float64
# BLK       float64
# TOV       float64
# PF        float64
# PTS       float64
# Awards     object
# dtype: object

# %%
data['Has award'] = data['Awards'].apply(lambda x: 0 if x == 'No awards' else 1)

# %%
data
# Out:
#      Season  Age   G  GS    MP    FG   FGA    FG%   3P  3PA  ...   DRB   TRB  \
# 1   2015-16   20  80  55  21.7   3.8   7.5  0.512  0.4  1.1  ...   4.7   7.0
# 2   2016-17   21  73  59  27.9   6.8  11.7  0.578  0.6  1.9  ...   6.9   9.8
# 3   2017-18   22  75  73  32.6   6.7  13.5  0.499  1.5  3.7  ...   8.1  10.7
# 4   2018-19   23  80  80  31.3   7.7  15.1  0.511  1.0  3.4  ...   8.0  10.8
# 5   2019-20   24  73  73  32.0   7.7  14.7  0.528  1.1  3.5  ...   7.5   9.7
# 6   2020-21   25  72  72  34.6  10.2  18.0  0.566  1.3  3.3  ...   8.0  10.8
# 7   2021-22   26  74  74  33.5  10.3  17.7  0.583  1.3  3.9  ...  11.0  13.8
# 8   2022-23   27  69  69  33.7   9.4  14.8  0.632  0.8  2.2  ...   9.4  11.8
# 9   2023-24   28  79  79  34.6  10.4  17.9  0.583  1.1  2.9  ...   9.5  12.4
# 10  2024-25   29  70  70  36.7  11.2  19.5  0.576  2.0  4.7  ...   9.9  12.7
#
#      AST  STL  BLK  TOV   PF   PTS              Awards  Has award
# ...

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(data['Season'], data['PTS'], marker='o', label='Points Per Game')
plt.plot(data['Season'], data['AST'], marker='o', label='Assist Per Game')
plt.plot(data['Season'], data['TRB'], marker='o', label='Rebounds Per Game')

plt.xticks(rotation=45)
plt.title('Nikola Jokic Scoring, Passing, Rebounding Progression')
plt.legend()
plt.show()
plt.clf()

# %%
plt.scatter(data['MP'], data['PTS'],c=data['Has award'], cmap='coolwarm', s=100)
plt.xlabel('Minutes Per Game')
plt.ylabel('Points Per Game')
plt.title('Efficiency vs Playing Time (Awards also Highlighted)')
plt.show()

# %%
plt.bar(data['Season'], data['PTS'], color=data['Has award'].map({1: 'gold', 0: 'navy'}))
plt.xticks(rotation=45)
plt.ylabel('Points Per Game')
plt.title("Nikola Jokic Points per Game (MVP Years Highlighted)")
plt.show()
plt.clf()
